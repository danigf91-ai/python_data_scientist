# %% [markdown]
# # SpaceX API Data Collection
# Completed IBM capstone API workflow.

# %%
import requests, pandas as pd, numpy as np
static_json_url='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/API_call_spacex_api.json'
response=requests.get(static_json_url)
data=pd.json_normalize(response.json())
data=data[['rocket','payloads','launchpad','cores','flight_number','date_utc']]

# %%
# After enrichment with the course helper functions, keep Falcon 9 only
data_falcon9=data_falcon9.copy()
payload_mean=data_falcon9['PayloadMass'].mean()
data_falcon9['PayloadMass']=data_falcon9['PayloadMass'].replace(np.nan,payload_mean)
data_falcon9.to_csv('dataset_part_1.csv',index=False)
